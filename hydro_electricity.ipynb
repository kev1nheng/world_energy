# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
energy = pd.read_csv('World Energy Consumption.csv')

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17432 entries, 0 to 17431
# Columns: 122 entries, iso_code to wind_energy_per_capita
# dtypes: float64(119), int64(1), object(2)
# memory usage: 16.2+ MB

# %%
energy.isnull().sum()/len(energy)*100
# Out:
# iso_code                  10.337311
# country                    0.000000
# year                       0.000000
# coal_prod_change_pct      57.291189
# coal_prod_change_twh      40.374025
#                             ...
# wind_share_energy         75.424507
# wind_cons_change_twh      75.866223
# wind_consumption          75.390087
# wind_elec_per_capita      68.454566
# wind_energy_per_capita    75.390087
# Length: 122, dtype: float64

# %%
energy.head(5)
# Out:
#   iso_code      country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0      AFG  Afghanistan  1900                   NaN                   NaN
# 1      AFG  Afghanistan  1901                   NaN                   0.0
# 2      AFG  Afghanistan  1902                   NaN                   0.0
# 3      AFG  Afghanistan  1903                   NaN                   0.0
# 4      AFG  Afghanistan  1904                   NaN                   0.0
#
#    gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    oil_prod_change_twh  energy_cons_change_pct  ...  solar_elec_per_capita  \
# ...

# %%
old_regime = pd.DataFrame(energy.loc[energy['iso_code'].isnull() == True])

# %%
old_regime
# Out:
#       iso_code     country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 120        NaN      Africa  1900                   NaN                   NaN
# 121        NaN      Africa  1901                67.810                 4.530
# 122        NaN      Africa  1902                49.068                 5.500
# 123        NaN      Africa  1903                35.697                 5.965
# 124        NaN      Africa  1904                12.880                 2.921
# ...        ...         ...   ...                   ...                   ...
# 17187      NaN  Yugoslavia  2012                 0.000                   NaN
# 17188      NaN  Yugoslavia  2013                 0.000                   NaN
# 17189      NaN  Yugoslavia  2014                 0.000                   NaN
# 17190      NaN  Yugoslavia  2015                 0.000                   NaN
# 17191      NaN  Yugoslavia  2016                 0.000                   NaN
#
# ...

# %%
energy = pd.DataFrame(energy.loc[energy['iso_code'].isnull() != True])

# %%
energy.isnull().sum()/len(energy)*100
# Out:
# iso_code                   0.000000
# country                    0.000000
# year                       0.000000
# coal_prod_change_pct      58.790787
# coal_prod_change_twh      40.166347
#                             ...
# wind_share_energy         73.646833
# wind_cons_change_twh      74.120282
# wind_consumption          73.608445
# wind_elec_per_capita      65.617402
# wind_energy_per_capita    73.608445
# Length: 122, dtype: float64

# %%
energy.fillna(0,inplace= True)

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15630 entries, 0 to 17431
# Columns: 122 entries, iso_code to wind_energy_per_capita
# dtypes: float64(119), int64(1), object(2)
# memory usage: 14.7+ MB

# %%
energy.isnull().sum()/len(energy)*100
# Out:
# iso_code                  0.0
# country                   0.0
# year                      0.0
# coal_prod_change_pct      0.0
# coal_prod_change_twh      0.0
#                          ...
# wind_share_energy         0.0
# wind_cons_change_twh      0.0
# wind_consumption          0.0
# wind_elec_per_capita      0.0
# wind_energy_per_capita    0.0
# Length: 122, dtype: float64

# %%
energy.dtypes
# Out:
# iso_code                   object
# country                    object
# year                        int64
# coal_prod_change_pct      float64
# coal_prod_change_twh      float64
#                            ...
# wind_share_energy         float64
# wind_cons_change_twh      float64
# wind_consumption          float64
# wind_elec_per_capita      float64
# wind_energy_per_capita    float64
# Length: 122, dtype: object

# %%
canada_energy = pd.DataFrame(energy.loc[energy['iso_code'] == 'CAN'])

# %%
canada_energy.drop(columns=['iso_code','country'],inplace = True)

# %%
canada_energy.set_index('year',inplace = True)

# %%
canada_energy.dtypes
# Out:
# coal_prod_change_pct      float64
# coal_prod_change_twh      float64
# gas_prod_change_pct       float64
# gas_prod_change_twh       float64
# oil_prod_change_pct       float64
#                            ...
# wind_share_energy         float64
# wind_cons_change_twh      float64
# wind_consumption          float64
# wind_elec_per_capita      float64
# wind_energy_per_capita    float64
# Length: 119, dtype: object

# %%
for i in ('coal_prod_change_pct','coal_prod_change_twh'):
    canada_energy[i].plot(legend=('coal_prod_change_pct','coal_prod_change_twh'))
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Open Sans, Source Sans Pro, Noto Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Open Sans, Source Sans Pro, Noto Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Open Sans, Source Sans Pro, Noto Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Open Sans, Source Sans Pro, Noto Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Open Sans, Source Sans Pro, Noto Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Open Sans, Source Sans Pro, Noto Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Open Sans, Source Sans Pro, Noto Sans
# ...

# %%
for i in ('hydro_share_elec','hydro_cons_change_pct','hydro_share_energy','hydro_cons_change_twh','hydro_consumption','hydro_elec_per_capita','hydro_energy_per_capita'):
    canada_energy[i].plot(legend=('hydro_share_elec',
                                  'hydro_cons_change_pct',
                                  'hydro_share_energy',
                                  'hydro_cons_change_twh',
                                  'hydro_consumption','hydro_elec_per_capita','hydro_energy_per_capita'))
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Open Sans, Source Sans Pro, Noto Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Open Sans, Source Sans Pro, Noto Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Open Sans, Source Sans Pro, Noto Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Open Sans, Source Sans Pro, Noto Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Open Sans, Source Sans Pro, Noto Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Open Sans, Source Sans Pro, Noto Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Open Sans, Source Sans Pro, Noto Sans
# ...
